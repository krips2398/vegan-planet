# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pltt

# %%
df = pd.read_csv('../data/vegetarian_restaurants_US_datafiniti.csv')

# %%
df.shape
# Out:
# (18155, 29)

# %%
df.sample(n=10)
# Out:
#                      address  \
# 1783        1317 E Carson St
# 5194            524 E 6th St
# 5964                     NaN
# 3151           700 E Main St
# 6481   4017 Saint Claude Ave
# 8074     11501 Rock Rose Ave
# 1741         43757 15th St W
# 14184     3111 Glendale Blvd
# 4329        1136 19th St N W
# 7362                     NaN
#
#                                               categories          city  \
# 1783   Health Food Restaurants, Box Lunches, Caterers...    Pittsburgh
# 5194   New American Restaurant, Vegetarian / Vegan Re...    Des Moines
# 5964                                                 NaN  Philadelphia
# 3151   ["Lake Zurich Restaurants","Pizza / Vegan / Ve...   Lake Zurich
# 6481            Vegetarian / Vegan Restaurant St. Claude   New Orleans
# 8074   Indian Restaurant and Vegetarian / Vegan Resta...        Austin
# 1741   Chinese Restaurants, Vegan Restaurants, Asian ...     Lancaster
# ...

# %%
df.columns
# Out:
# Index(['address', 'categories', 'city', 'claimed', 'country', 'cuisines',
#        'dateOpened', 'dateUpdated', 'descriptions', 'facebookPageURL',
#        'features', 'hours', 'images', 'isClosed', 'key', 'lat', 'languages',
#        'long', 'menus', 'menuURL', 'name', 'paymentTypes', 'phones',
#        'postalCode', 'priceRange', 'province', 'sic', 'twitter', 'websites'],
#       dtype='object')

# %%
df['menus'][2]
# Out:
# '[{"descriptions":"create your own full slab. pair up a 1/2 slab of hicko4ry-smoked st. louis-style spareribs with a 1/2 slab of our lip smackin baby backs.","name":"Rib N Rib Bbq Combo"},{"descriptions":"St. louis-style spareribs are just the starter. add fried chicken tenders, chili-roasted corn fritters, onion strings and traditional or boneless wings tossed in your choice of sauce.","name":"Dave\'s Sampler Platter"},{"descriptions":"slathered with devil\'s spit bbq sauce and topped with pepper-jack cheese, jalapeno bacon and hell fire pickle chips","name":"Devil\'s Spit Burger"},{"descriptions":"smoked for up to 12 hours and chopped to order, our award-winning bbq pork is juicier than a georgia peach.","name":"Georgia Chopped Pork"},{"descriptions":"tri-tip seasoned with our own sweet and spicy rub, hickory smoked then sliced and served over texas toast.","name":"Smoked Sirloin Tri-tip Platter"},{"descriptions":"georgia chopped pork, texas beef brisket, barbeque Pulled chicken wi
# ...

# %%
df['cuisines']
# Out:
# 0                                                      NaN
# 1                                Vegetarian,  Delicatessen
# 2                                                      NaN
# 3        Coffee & Tea, Restaurants, American,  Bar,  Pu...
# 4        Take Out Restaurants, Asian Restaurants, Resta...
#                                ...
# 18150                                                  NaN
# 18151                               American, ��Vegetarian
# 18152                                                  NaN
# 18153    ["Mediterranean","Restaurants","Family Style",...
# 18154                                                  NaN
# Name: cuisines, Length: 18155, dtype: object

# %%
# Out:
# 0        Village Inn Restaurant and Bakery
# 1                           Atlantic No. 5
# 2                            Famous Dave's
# 3                                 The Feve
# 4                                  Quiznos
#                        ...
# 18150               The Old Man River Cafe
# 18151                      The Melting Pot
# 18152                        Smoothie King
# 18153                        Buca Di Beppo
# 18154                         Grotto Pizza
# Name: name, Length: 18155, dtype: object
